# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaimaM/Intro_to_ML/blob/main/airbnb_price_regression_starter_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dammam_link = 'https://github.com/gumdropsteve/intro_to_machine_learning/raw/main/day_10/data/dammam.parquet'

df=pd.read_parquet(dammam_link)
df.head()
# Out:
#                            ds  ... chefs_kitchen_bool
# 0  2021-01-20 03:52:47.315742  ...              False
# 1  2021-01-20 03:52:47.315742  ...              False
# 2  2021-01-20 03:52:47.315742  ...              False
# 3  2021-01-20 03:52:47.315742  ...              False
# 4  2021-01-20 03:52:47.315742  ...              False
#
# [5 rows x 40 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ####Date Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3015 entries, 0 to 3014
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ds                       3015 non-null   object
#  1   search_filter            2009 non-null   object
#  2   url                      3015 non-null   object
#  3   title                    3015 non-null   object
#  4   type                     3015 non-null   object
#  5   location                 3015 non-null   object
#  6   guests                   1907 non-null   float64
#  7   bedrooms                 3015 non-null   float64
#  8   beds                     1907 non-null   float64
#  9   is_studio                3015 non-null   bool
#  10  baths                    2051 non-null   float64
#  11  half_baths               0 non-null      float64
#  12  shared_baths             21 non-null     float64
#  13  price                    3015 non-null   float64
#  14  avg_rating               1001 non-null   float64
#  15  n_reviews                1001 non-null   float64
#  16  gym_bool                 3015 non-null   bool
#  17  wifi_bool                3015 non-null   bool
#  18  self_check_in_bool       3015 non-null   bool
#  19  air_conditioning_bool    3015 non-null   bool
#  20  pets_allowed_bool        3015 non-null   bool
#  21  indoor_fireplace_bool    3015 non-null   bool
#  22  hot_tub_bool             3015 non-null   bool
#  23  free_parking_bool        3015 non-null   bool
#  24  pool_bool                3015 non-null   bool
#  25  kitchen_bool             3015 non-null   bool
#  26  breakfast_bool           3015 non-null   bool
#  27  elevator_bool            3015 non-null   bool
#  28  washer_bool              3015 non-null   bool
#  29  dryer_bool               3015 non-null   bool
#  30  heating_bool             3015 non-null   bool
#  31  waterfront_bool          3015 non-null   bool
#  32  dishwasher_bool          3015 non-null   bool
#  33  beachfront_bool          3015 non-null   bool
#  34  ski_in_ski_out_bool      3015 non-null   bool
#  35  terrace_bool             3015 non-null   bool
#  36  sonos_sound_system_bool  3015 non-null   bool
#  37  bbq_grill_bool           3015 non-null   bool
#  38  hair_dryer_bool          3015 non-null   bool
#  39  chefs_kitchen_bool       3015 non-null   bool
# dtypes: bool(25), float64(9), object(6)
# memory usage: 427.1+ KB

# %%
df.describe()
# Out:
#             guests     bedrooms  ...   avg_rating    n_reviews
# count  1907.000000  3015.000000  ...  1001.000000  1001.000000
# mean      2.487677     1.373134  ...     4.454466    11.054945
# std       1.763341     1.531274  ...     0.783735     8.586966
# min       0.000000     0.000000  ...     2.500000     3.000000
# 25%       2.000000     1.000000  ...     4.170000     4.000000
# 50%       2.000000     1.000000  ...     4.900000    10.000000
# 75%       3.000000     2.000000  ...     5.000000    15.000000
# max      14.000000    50.000000  ...     5.000000    89.000000
#
# [8 rows x 9 columns]

# %%
df.shape
# Out:
# (3015, 40)

# %% [markdown]
# ####Prococing

# %%
df.isnull().sum()
# Out:
# ds                            0
# search_filter              1006
# url                           0
# title                         0
# type                          0
# location                      0
# guests                     1108
# bedrooms                      0
# beds                       1108
# is_studio                     0
# baths                       964
# half_baths                 3015
# shared_baths               2994
# price                         0
# avg_rating                 2014
# n_reviews                  2014
# gym_bool                      0
# wifi_bool                     0
# self_check_in_bool            0
# air_conditioning_bool         0
# pets_allowed_bool             0
# indoor_fireplace_bool         0
# hot_tub_bool                  0
# free_parking_bool             0
# pool_bool                     0
# kitchen_bool                  0
# breakfast_bool                0
# elevator_bool                 0
# washer_bool                   0
# dryer_bool                    0
# heating_bool                  0
# waterfront_bool               0
# dishwasher_bool               0
# beachfront_bool               0
# ski_in_ski_out_bool           0
# terrace_bool                  0
# sonos_sound_system_bool       0
# bbq_grill_bool                0
# hair_dryer_bool               0
# chefs_kitchen_bool            0
# dtype: int64

# %%
missing_val = df.isnull().sum()
missing_val[missing_val>0]
# Out:
# search_filter    1006
# guests           1108
# beds             1108
# baths             964
# half_baths       3015
# shared_baths     2994
# avg_rating       2014
# n_reviews        2014
# dtype: int64

# %%
#calculate percentage of missing values
missing_percentage = missing_val/(len(df))*100
missing_percentage.sort_values(inplace=True)

# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# magic word for producing visualizations in notebook
# %matplotlib inline

# %%
#plot missing values in each columns
import seaborn as sns    
# %matplotlib inline
plt.rcParams['figure.figsize']=(7,8)
#missingValues_columns = missingValues_columns[missingValues_columns > 0]/(azdias_clean.shape[0])

missingValues_columns =(df.isnull().sum()/len(df))*100
sns.distplot(missingValues_columns, kde = False).set_title('plot of missing value rates');
plt.xlabel('rate of missing data (%)')
plt.ylabel('rate of columns')
plt.show();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Investigate patterns in the amount of missing data in each column.
missingValues_columns.sort_values(inplace=True)
missingValues_columns.plot.barh(figsize=(20,20))
plt.xlabel('Columns name includes missing data')
plt.ylabel('missing data (%)')
plt.title("amount of missing data in each column")

plt.show();

# %%
import missingno as msno
# confusion matrix for missing values
msno.heatmap(df);

# %%
df =df.drop(columns=['half_baths','shared_baths'])

# %%
df['n_reviews'] = df['n_reviews'].fillna(df['n_reviews'].mode()[0])

# %%
df['avg_rating'] = df['avg_rating'].fillna(df['avg_rating'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ds                            0
# search_filter              1006
# url                           0
# title                         0
# type                          0
# location                      0
# guests                     1108
# bedrooms                      0
# beds                       1108
# is_studio                     0
# baths                       964
# price                         0
# avg_rating                    0
# n_reviews                     0
# gym_bool                      0
# wifi_bool                     0
# self_check_in_bool            0
# air_conditioning_bool         0
# pets_allowed_bool             0
# indoor_fireplace_bool         0
# hot_tub_bool                  0
# free_parking_bool             0
# pool_bool                     0
# kitchen_bool                  0
# breakfast_bool                0
# elevator_bool                 0
# washer_bool                   0
# dryer_bool                    0
# heating_bool                  0
# waterfront_bool               0
# dishwasher_bool               0
# beachfront_bool               0
# ski_in_ski_out_bool           0
# terrace_bool                  0
# sonos_sound_system_bool       0
# bbq_grill_bool                0
# hair_dryer_bool               0
# chefs_kitchen_bool            0
# dtype: int64

# %%
df['guests'] = df['guests'].fillna(df['guests'].mean())

# %%
df['beds'] = df['beds'].fillna(df['beds'].mean())

# %%
df['baths'] = df['baths'].fillna(df['baths'].mean())

# %%
df.search_filter.unique()
# Out:
# array([None, 'super_hosts', 'entire_homes', 'entire_home_super_hosts',
#        'hotel_rooms', 'private_rooms', 'shared_rooms'], dtype=object)

# %%
df['search_filter'].astype(str)
# Out:
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
#             ...
# 3010    shared_rooms
# 3011    shared_rooms
# 3012    shared_rooms
# 3013    shared_rooms
# 3014    shared_rooms
# Name: search_filter, Length: 3015, dtype: object

# %%
df['search_filter'].fillna('No Value', inplace=True)

# %%
df.isnull().sum()
# Out:
# ds                         0
# search_filter              0
# url                        0
# title                      0
# type                       0
# location                   0
# guests                     0
# bedrooms                   0
# beds                       0
# is_studio                  0
# baths                      0
# price                      0
# avg_rating                 0
# n_reviews                  0
# gym_bool                   0
# wifi_bool                  0
# self_check_in_bool         0
# air_conditioning_bool      0
# pets_allowed_bool          0
# indoor_fireplace_bool      0
# hot_tub_bool               0
# free_parking_bool          0
# pool_bool                  0
# kitchen_bool               0
# breakfast_bool             0
# elevator_bool              0
# washer_bool                0
# dryer_bool                 0
# heating_bool               0
# waterfront_bool            0
# dishwasher_bool            0
# beachfront_bool            0
# ski_in_ski_out_bool        0
# terrace_bool               0
# sonos_sound_system_bool    0
# bbq_grill_bool             0
# hair_dryer_bool            0
# chefs_kitchen_bool         0
# dtype: int64

# %%
df.head()
# Out:
#                            ds  ... chefs_kitchen_bool
# 0  2021-01-20 03:52:47.315742  ...              False
# 1  2021-01-20 03:52:47.315742  ...              False
# 2  2021-01-20 03:52:47.315742  ...              False
# 3  2021-01-20 03:52:47.315742  ...              False
# 4  2021-01-20 03:52:47.315742  ...              False
#
# [5 rows x 38 columns]

# %%
#convert ds to datatime
df['DateTime'] = pd.to_datetime(df['ds'])

# %%
#split year into new column
df['year'] = df['DateTime'].dt.year
#split month into new column
df['month'] = df['DateTime'].dt.month
#split day into new column
df['day'] = df['DateTime'].dt.day

# %%
df.head(1)
# Out:
#                            ds search_filter  ... month day
# 0  2021-01-20 03:52:47.315742      No Value  ...     1  20
#
# [1 rows x 42 columns]

# %%
df.drop(['ds', 'url', 'DateTime', 'title'], axis=1, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 202

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#df['url'].to_string()

# %%
#df['url'].astype(str)

# %%
df.location.unique()
# Out:
# array(['Al Khobar', 'Dammam', 'Aziziah', 'Dhahran', 'serviced apartment',
#        'Dammam ', 'Khobar ', 'Az Zahran', 'Arrakah ', 'Khobar',
#        'الدمام\u200e', 'Eastern Province', 'الخبر', 'Seef', 'Manama',
#        'Sea Front', 'Muharraq Governorate', 'Al Maqsha',
#        'Dilmonia Island', 'Amwaj Islands', 'Half Moon Bay',
#        'Al Khobar, Dhahran', 'Durrat Al Bahrain', 'Al Markh', 'المنامة',
#        'Al-Muḥāfaẓat aš-Šamālīyah', 'Al Eker', 'boutique hotel'],
#       dtype=object)

# %%
df.location = df['location'].replace(['الخبر','Khobar', 'Khobar ', 'Eastern Province'],'Al Khobar')
df.location = df['location'].replace(['Al Khobar, Dhahran'],'Dhahran')
df.location = df['location'].replace(['الدمام\u200e', 'Dammam '],'Dammam')
df.location = df['location'].replace(['المنامة'],'Manama')

# %%
df.head()
# Out:
#   search_filter              type   location  ...  year  month  day
# 0      No Value  Entire apartment  Al Khobar  ...  2021      1   20
# 1      No Value  Entire apartment  Al Khobar  ...  2021      1   20
# 2      No Value  Entire apartment  Al Khobar  ...  2021      1   20
# 3      No Value  Entire apartment     Dammam  ...  2021      1   20
# 4      No Value  Entire apartment  Al Khobar  ...  2021      1   20
#
# [5 rows x 38 columns]

# %%
df.is_studio.unique()
# Out:
# array([False,  True])

# %%
for col in df.columns[df.dtypes == 'bool']:
    df[col] = df[col].map({True: 1, False: 0})

# %%
df.head()
# Out:
#   search_filter              type   location  ...  year  month  day
# 0      No Value  Entire apartment  Al Khobar  ...  2021      1   20
# 1      No Value  Entire apartment  Al Khobar  ...  2021      1   20
# 2      No Value  Entire apartment  Al Khobar  ...  2021      1   20
# 3      No Value  Entire apartment     Dammam  ...  2021      1   20
# 4      No Value  Entire apartment  Al Khobar  ...  2021      1   20
#
# [5 rows x 38 columns]

# %%
cat_col = [col for col in df.columns if df[col].dtype=='O']
cat_col
# Out:
# ['search_filter', 'type', 'location']

# %%
categorical = df[cat_col]
categorical.head()
# Out:
#   search_filter              type   location
# 0      No Value  Entire apartment  Al Khobar
# 1      No Value  Entire apartment  Al Khobar
# 2      No Value  Entire apartment  Al Khobar
# 3      No Value  Entire apartment     Dammam
# 4      No Value  Entire apartment  Al Khobar

# %%
int_col = [col for col in df.columns if df[col].dtype!='O']
int_col
# Out:
# ['guests',
#  'bedrooms',
#  'beds',
#  'is_studio',
#  'baths',
#  'price',
#  'avg_rating',
#  'n_reviews',
#  'gym_bool',
#  'wifi_bool',
#  'self_check_in_bool',
#  'air_conditioning_bool',
#  'pets_allowed_bool',
#  'indoor_fireplace_bool',
#  'hot_tub_bool',
#  'free_parking_bool',
#  'pool_bool',
#  'kitchen_bool',
#  'breakfast_bool',
#  'elevator_bool',
#  'washer_bool',
#  'dryer_bool',
#  'heating_bool',
#  'waterfront_bool',
#  'dishwasher_bool',
#  'beachfront_bool',
#  'ski_in_ski_out_bool',
#  'terrace_bool',
#  'sonos_sound_system_bool',
#  'bbq_grill_bool',
#  'hair_dryer_bool',
#  'chefs_kitchen_bool',
#  'year',
#  'month',
#  'day']

# %%
categorical_dum = pd.get_dummies(categorical)
categorical_dum.head()
# Out:
#    search_filter_No Value  ...  location_serviced apartment
# 0                       1  ...                            0
# 1                       1  ...                            0
# 2                       1  ...                            0
# 3                       1  ...                            0
# 4                       1  ...                            0
#
# [5 rows x 43 columns]

# %%
categorical_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2813 entries, 0 to 3014
# Data columns (total 43 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   search_filter_No Value                 2813 non-null   uint8
#  1   search_filter_entire_home_super_hosts  2813 non-null   uint8
#  2   search_filter_entire_homes             2813 non-null   uint8
#  3   search_filter_hotel_rooms              2813 non-null   uint8
#  4   search_filter_private_rooms            2813 non-null   uint8
#  5   search_filter_shared_rooms             2813 non-null   uint8
#  6   search_filter_super_hosts              2813 non-null   uint8
#  7   type_Camper/RV                         2813 non-null   uint8
#  8   type_Earth house                       2813 non-null   uint8
#  9   type_Entire apartment                  2813 non-null   uint8
#  10  type_Entire bungalow                   2813 non-null   uint8
#  11  type_Entire chalet                     2813 non-null   uint8
#  12  type_Entire house                      2813 non-null   uint8
#  13  type_Entire loft                       2813 non-null   uint8
#  14  type_Entire place                      2813 non-null   uint8
#  15  type_Entire serviced apartment         2813 non-null   uint8
#  16  type_Entire townhouse                  2813 non-null   uint8
#  17  type_Entire villa                      2813 non-null   uint8
#  18  type_Farm stay                         2813 non-null   uint8
#  19  type_Hotel room                        2813 non-null   uint8
#  20  type_Private room                      2813 non-null   uint8
#  21  type_Room                              2813 non-null   uint8
#  22  type_Shared room                       2813 non-null   uint8
#  23  location_Al Eker                       2813 non-null   uint8
#  24  location_Al Khobar                     2813 non-null   uint8
#  25  location_Al Maqsha                     2813 non-null   uint8
#  26  location_Al Markh                      2813 non-null   uint8
#  27  location_Al-Muḥāfaẓat aš-Šamālīyah     2813 non-null   uint8
#  28  location_Amwaj Islands                 2813 non-null   uint8
#  29  location_Arrakah                       2813 non-null   uint8
#  30  location_Az Zahran                     2813 non-null   uint8
#  31  location_Aziziah                       2813 non-null   uint8
#  32  location_Dammam                        2813 non-null   uint8
#  33  location_Dhahran                       2813 non-null   uint8
#  34  location_Dilmonia Island               2813 non-null   uint8
#  35  location_Durrat Al Bahrain             2813 non-null   uint8
#  36  location_Half Moon Bay                 2813 non-null   uint8
#  37  location_Manama                        2813 non-null   uint8
#  38  location_Muharraq Governorate          2813 non-null   uint8
#  39  location_Sea Front                     2813 non-null   uint8
#  40  location_Seef                          2813 non-null   uint8
#  41  location_boutique hotel                2813 non-null   uint8
#  42  location_serviced apartment            2813 non-null   uint8
# dtypes: uint8(43)
# memory usage: 140.1 KB

# %%
df_new = pd.concat(
    [df,
     categorical_dum],
      axis=1)
df_new
# Out:
#      search_filter  ... location_serviced apartment
# 0         No Value  ...                           0
# 1         No Value  ...                           0
# 2         No Value  ...                           0
# 3         No Value  ...                           0
# 4         No Value  ...                           0
# ...            ...  ...                         ...
# 3006  shared_rooms  ...                           0
# 3008  shared_rooms  ...                           0
# 3010  shared_rooms  ...                           0
# 3012  shared_rooms  ...                           0
# 3014  shared_rooms  ...                           0
#
# [2813 rows x 81 columns]
